# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
import numpy as np
from glob import glob
from PIL import Image
import matplotlib.pyplot as plt
import re
import os

# %%
image_datas = glob('./chinese_foods/*/*.jpg')
class_name = ["congee", "dong_po_rou", "baozi", "chaofan", "zhajiangmian",
                  "sweet_and_sour_pork", "mapotofu", "wonton_soup", "mooncake", "pecking_duck"]
dic = {"congee":0, "dong_po_rou":1, "baozi":2, "chaofan":3, "zhajiangmian":4,
                  "sweet_and_sour_pork":5, "mapotofu":6, "wonton_soup":7, "mooncake":8, "pecking_duck":9}

# %%
X = []
Y = []
for imagename in image_datas:
    image = Image.open(imagename)
    image = image.resize((128, 128))
    image = np.array(image)
    X.append(image)
    label = imagename.split('\\')[2].replace('.jpg','').replace(' ','')
    label = re.sub(r"[0-9]", "", label)
    label = label[:-1]
    label = dic[label]
    Y.append(label)

# %%
X = np.array(X)    
Y = np.array(Y)

# %%
train_images, test_images, train_labels, test_labels = train_test_split(X, Y, test_size=0.2, 
                                                    shuffle=True, random_state=44)

train_labels = train_labels[..., tf.newaxis]
test_labels = test_labels[..., tf.newaxis]

train_images.shape, train_labels.shape, test_images.shape, test_labels.shape
# Out:
# ((875, 128, 128, 3), (875, 1), (219, 128, 128, 3), (219, 1))

# %%
## training set의 각 class 별 image 수 확인
unique, counts = np.unique(np.reshape(train_labels, (875,)), axis=-1, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 86, 1: 99, 2: 79, 3: 97, 4: 66, 5: 93, 6: 87, 7: 93, 8: 83, 9: 92}

# %%
## test set의 각 class 별 image 수 확인
unique, counts = np.unique(np.reshape(test_labels, (219,)), axis=-1, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 26, 1: 25, 2: 27, 3: 25, 4: 19, 5: 17, 6: 20, 7: 21, 8: 18, 9: 21}

# %%
N_TRAIN = train_images.shape[0]
N_TEST = test_images.shape[0]

# %%
## Data 확인
plt.figure(figsize=(15,9))
for i in range(15):
    img_idx = np.random.randint(0, 875)
    plt.subplot(3,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[img_idx])
    plt.xlabel(class_name[train_labels[img_idx][0]])

# %%
# pixel값을 0~1사이 범위로 조정
train_images = train_images.astype(np.float32) / 255.
test_images = test_images.astype(np.float32) / 255.

# label을 onehot-encoding
train_labels = keras.utils.to_categorical(train_labels)
test_labels = keras.utils.to_categorical(test_labels)

# %%
print(train_images.shape, train_labels.shape)
print(test_images.shape, test_labels.shape)
# Out:
# (875, 128, 128, 3) (875, 10)
# (219, 128, 128, 3) (219, 10)

# %%
## Hyper-parameters
learning_rate = 0.0001
N_EPOCHS = 50
N_BATCH = 40
N_CLASS = 10

# %%
## dataset 구성    
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels)).shuffle(
                buffer_size=875).batch(N_BATCH).repeat()
test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels)).batch(
				N_BATCH)

# %%
# Sequential API를 사용하여 model 구성
def create_model():
    model = keras.Sequential()
    model.add(keras.layers.Conv2D(filters=32, kernel_size=3, 
                                  activation='relu', padding='SAME', 
                                  input_shape=(128, 128, 3)))
    model.add(keras.layers.MaxPool2D(padding='SAME'))
    model.add(keras.layers.Conv2D(filters=64, kernel_size=3, 
                                  activation='relu', padding='SAME'))
    model.add(keras.layers.MaxPool2D(padding='SAME'))
    model.add(keras.layers.Conv2D(filters=128, kernel_size=3, 
                                  activation='relu', padding='SAME'))
    model.add(keras.layers.MaxPool2D(padding='SAME'))
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(256, activation='relu'))
    model.add(keras.layers.Dropout(0.4))
    model.add(keras.layers.Dense(10, activation='softmax'))
    return model

# %%
## Create model, compile & summary
model = create_model()
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 256)               8388864
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 8,484,682
# Trainable params: 8,484,682
# Non-trainable params: 0
# _________________________________________________________________

# %%
## Parameters for training
steps_per_epoch = N_TRAIN//N_BATCH
validation_steps = N_TEST//N_BATCH
print(steps_per_epoch, validation_steps)
# Out:
# 21 5

# %%
## Training
history = model.fit(train_dataset, epochs=N_EPOCHS, steps_per_epoch=steps_per_epoch, 
                    validation_data=test_dataset, validation_steps=validation_steps)
# Out:
# Epoch 1/50
# 21/21 [==============================] - 12s 523ms/step - loss: 2.2988 - accuracy: 0.1190 - val_loss: 2.2384 - val_accuracy: 0.1800
# Epoch 2/50
# 21/21 [==============================] - 11s 530ms/step - loss: 2.1461 - accuracy: 0.2228 - val_loss: 2.0208 - val_accuracy: 0.2850
# Epoch 3/50
# 21/21 [==============================] - 11s 513ms/step - loss: 1.9505 - accuracy: 0.2814 - val_loss: 1.8005 - val_accuracy: 0.3700
# Epoch 4/50
# 21/21 [==============================] - 11s 510ms/step - loss: 1.8020 - accuracy: 0.3341 - val_loss: 1.6793 - val_accuracy: 0.3750
# Epoch 5/50
# 21/21 [==============================] - 11s 520ms/step - loss: 1.6875 - accuracy: 0.3581 - val_loss: 1.5957 - val_accuracy: 0.4050
# Epoch 6/50
# 21/21 [==============================] - 11s 528ms/step - loss: 1.6090 - accuracy: 0.3760 - val_loss: 1.5204 - val_accuracy: 0.4400
# Epoch 7/50
# 21/21 [==============================] - 11s 522ms/step - loss: 1.4455 - accuracy: 0.4671 - val_loss: 1.5005 - val_accuracy: 0.3900
# Epoch 8/50
# 21/21 [==============================] - 11s 511ms/step - loss: 1.4160 - accuracy: 0.4874 - val_loss: 1.4195 - val_accuracy: 0.4400
# Epoch 9/50
# 21/21 [==============================] - 11s 530ms/step - loss: 1.2357 - accuracy: 0.5808 - val_loss: 1.3774 - val_accuracy: 0.4500
# Epoch 10/50
# 21/21 [==============================] - 11s 537ms/step - loss: 1.1611 - accuracy: 0.5844 - val_loss: 1.3352 - val_accuracy: 0.5000
# Epoch 11/50
# 21/21 [==============================] - 11s 526ms/step - loss: 1.1429 - accuracy: 0.6084 - val_loss: 1.3429 - val_accuracy: 0.4400
# Epoch 12/50
# 21/21 [==============================] - 11s 541ms/step - loss: 1.0616 - accuracy: 0.6240 - val_loss: 1.3502 - val_accuracy: 0.4750
# Epoch 13/50
# 21/21 [==============================] - 11s 520ms/step - loss: 0.9886 - accuracy: 0.6551 - val_loss: 1.2937 - val_accuracy: 0.4600
# Epoch 14/50
# 21/21 [==============================] - 11s 520ms/step - loss: 0.9326 - accuracy: 0.6850 - val_loss: 1.2714 - val_accuracy: 0.5050
# Epoch 15/50
# 21/21 [==============================] - 11s 521ms/step - loss: 0.8258 - accuracy: 0.7246 - val_loss: 1.3110 - val_accuracy: 0.5200
# Epoch 16/50
# 21/21 [==============================] - 11s 542ms/step - loss: 0.8394 - accuracy: 0.7246 - val_loss: 1.2777 - val_accuracy: 0.5000
# Epoch 17/50
# 21/21 [==============================] - 11s 539ms/step - loss: 0.7468 - accuracy: 0.7641 - val_loss: 1.2988 - val_accuracy: 0.4900
# Epoch 18/50
# 21/21 [==============================] - 11s 517ms/step - loss: 0.6667 - accuracy: 0.7892 - val_loss: 1.2892 - val_accuracy: 0.5150
# Epoch 19/50
# 21/21 [==============================] - 11s 521ms/step - loss: 0.6550 - accuracy: 0.7880 - val_loss: 1.2538 - val_accuracy: 0.5150
# Epoch 20/50
# 21/21 [==============================] - 11s 527ms/step - loss: 0.5737 - accuracy: 0.8299 - val_loss: 1.2379 - val_accuracy: 0.5300
# Epoch 21/50
# 21/21 [==============================] - 11s 513ms/step - loss: 0.5364 - accuracy: 0.8251 - val_loss: 1.3310 - val_accuracy: 0.5050
# Epoch 22/50
# 21/21 [==============================] - 11s 524ms/step - loss: 0.4972 - accuracy: 0.8467 - val_loss: 1.3158 - val_accuracy: 0.5200
# Epoch 23/50
# 21/21 [==============================] - 11s 521ms/step - loss: 0.4616 - accuracy: 0.8631 - val_loss: 1.2816 - val_accuracy: 0.5300
# Epoch 24/50
# 21/21 [==============================] - 11s 524ms/step - loss: 0.4121 - accuracy: 0.8814 - val_loss: 1.3683 - val_accuracy: 0.5300
# Epoch 25/50
# 21/21 [==============================] - 11s 515ms/step - loss: 0.3749 - accuracy: 0.8958 - val_loss: 1.3177 - val_accuracy: 0.5350
# Epoch 26/50
# 21/21 [==============================] - 11s 522ms/step - loss: 0.3168 - accuracy: 0.9174 - val_loss: 1.3685 - val_accuracy: 0.5300
# Epoch 27/50
# 21/21 [==============================] - 11s 530ms/step - loss: 0.2895 - accuracy: 0.9269 - val_loss: 1.3155 - val_accuracy: 0.5150
# Epoch 28/50
# 21/21 [==============================] - 11s 520ms/step - loss: 0.2619 - accuracy: 0.9365 - val_loss: 1.4465 - val_accuracy: 0.5000
# Epoch 29/50
# 21/21 [==============================] - 11s 516ms/step - loss: 0.2708 - accuracy: 0.9317 - val_loss: 1.4247 - val_accuracy: 0.5300
# Epoch 30/50
# 21/21 [==============================] - 11s 519ms/step - loss: 0.2290 - accuracy: 0.9485 - val_loss: 1.4970 - val_accuracy: 0.5100
# Epoch 31/50
# 21/21 [==============================] - 11s 527ms/step - loss: 0.2077 - accuracy: 0.9485 - val_loss: 1.4869 - val_accuracy: 0.5200
# Epoch 32/50
# 21/21 [==============================] - 11s 528ms/step - loss: 0.1840 - accuracy: 0.9593 - val_loss: 1.5613 - val_accuracy: 0.4800
# Epoch 33/50
# 21/21 [==============================] - 11s 514ms/step - loss: 0.1680 - accuracy: 0.9569 - val_loss: 1.5616 - val_accuracy: 0.4950
# Epoch 34/50
# 21/21 [==============================] - 11s 515ms/step - loss: 0.1694 - accuracy: 0.9617 - val_loss: 1.5456 - val_accuracy: 0.4950
# Epoch 35/50
# 21/21 [==============================] - 11s 526ms/step - loss: 0.1483 - accuracy: 0.9629 - val_loss: 1.5349 - val_accuracy: 0.5200
# Epoch 36/50
# 21/21 [==============================] - 11s 526ms/step - loss: 0.1524 - accuracy: 0.9689 - val_loss: 1.5613 - val_accuracy: 0.5400
# Epoch 37/50
# 21/21 [==============================] - 11s 517ms/step - loss: 0.1338 - accuracy: 0.9737 - val_loss: 1.6470 - val_accuracy: 0.4850
# Epoch 38/50
# 21/21 [==============================] - 11s 514ms/step - loss: 0.1468 - accuracy: 0.9677 - val_loss: 1.5534 - val_accuracy: 0.5250
# Epoch 39/50
# 21/21 [==============================] - 11s 534ms/step - loss: 0.1153 - accuracy: 0.9808 - val_loss: 1.6598 - val_accuracy: 0.4800
# Epoch 40/50
# 21/21 [==============================] - 11s 522ms/step - loss: 0.1248 - accuracy: 0.9737 - val_loss: 1.5436 - val_accuracy: 0.5300
# Epoch 41/50
# 21/21 [==============================] - 11s 516ms/step - loss: 0.1254 - accuracy: 0.9653 - val_loss: 1.6391 - val_accuracy: 0.5100
# Epoch 42/50
# 21/21 [==============================] - 12s 551ms/step - loss: 0.1149 - accuracy: 0.9760 - val_loss: 1.7095 - val_accuracy: 0.4750
# Epoch 43/50
# 21/21 [==============================] - 12s 586ms/step - loss: 0.0929 - accuracy: 0.9796 - val_loss: 1.7760 - val_accuracy: 0.4750
# Epoch 44/50
# 21/21 [==============================] - 13s 622ms/step - loss: 0.1077 - accuracy: 0.9749 - val_loss: 1.7111 - val_accuracy: 0.5100
# Epoch 45/50
# 21/21 [==============================] - 15s 715ms/step - loss: 0.0863 - accuracy: 0.9821 - val_loss: 1.7284 - val_accuracy: 0.4800
# Epoch 46/50
# 21/21 [==============================] - 13s 634ms/step - loss: 0.0814 - accuracy: 0.9856 - val_loss: 1.7476 - val_accuracy: 0.5000
# Epoch 47/50
# 21/21 [==============================] - 13s 625ms/step - loss: 0.0744 - accuracy: 0.9880 - val_loss: 1.6637 - val_accuracy: 0.5200
# Epoch 48/50
# 21/21 [==============================] - 12s 570ms/step - loss: 0.0782 - accuracy: 0.9832 - val_loss: 1.6841 - val_accuracy: 0.5100
# Epoch 49/50
# 21/21 [==============================] - 14s 647ms/step - loss: 0.0700 - accuracy: 0.9892 - val_loss: 1.6558 - val_accuracy: 0.5100
# Epoch 50/50
# 21/21 [==============================] - 11s 535ms/step - loss: 0.0501 - accuracy: 0.9940 - val_loss: 1.8390 - val_accuracy: 0.4950

# %%
model.evaluate(test_dataset)
# Out:
# 6/6 [==============================] - 1s 107ms/step - loss: 1.8361 - accuracy: 0.5068
# [1.8361260890960693, 0.5068492889404297]

# %%
## Plot losses
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
## Plot accuracy
plt.plot(history.history['accuracy'], 'b-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'r--', label='val_accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
## 결과 확인
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_name[predicted_label],
                                100*np.max(predictions_array),
                                class_name[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    #plt.xticks([])
    plt.xticks(range(N_CLASS), class_name, rotation=90)
    plt.yticks([])
    thisplot = plt.bar(range(N_CLASS), predictions_array, color="#777777")
    plt.ylim([0, 1]) 
    predicted_label = np.argmax(predictions_array)
 
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
rnd_idx = np.random.randint(1, N_TEST//N_BATCH)
img_cnt = 0
for images, labels in test_dataset:
    img_cnt += 1
    if img_cnt != rnd_idx:
        continue
    predictions = model(images, training=False)
    num_rows = 5
    num_cols = 3
    num_images = num_rows*num_cols
    labels = tf.argmax(labels, axis=-1)
    plt.figure(figsize=(3*2*num_cols, 4*num_rows))
    plt.subplots_adjust(hspace=1.0)
    for i in range(num_images):
        plt.subplot(num_rows, 2*num_cols, 2*i+1)
        plot_image(i, predictions.numpy(), labels.numpy(), images.numpy())
        plt.subplot(num_rows, 2*num_cols, 2*i+2)
        plot_value_array(i, predictions.numpy(), labels.numpy())        
    break

# %%
cur_dir = os.getcwd() #현재 작업디렉토리
ckpt_dir = 'checkpoints' #weight를 저장할 디렉토리
file_name = 'chinese_cnn_weights.h5' #저장파일명

dir = os.path.join(cur_dir, ckpt_dir)
os.makedirs(dir, exist_ok=True)

file_path = os.path.join(dir, file_name)

# %%
model.save(file_path)

# %%
food_kcal = {"congee":190, "dong_po_rou":926, "baozi":510, "chaofan":950, "zhajiangmian":864,
                  "sweet_and_sour_pork":481, "mapotofu":290, "wonton_soup":205, "mooncake":400, "pecking_duck":474}

# %%
testimg_datas = glob('./test_img/*.jpg')

X2 = []
Y2 = []
for testimgname in testimg_datas:
    image = Image.open(testimgname)
    image = image.resize((128, 128))
    image = np.array(image)
    X2.append(image)
    label = testimgname.split('\\')[1].replace('.jpg','').replace(' ','')
    Y2.append(label)

X2 = np.array(X2)  

# pixel값을 0~1사이 범위로 조정
X2 = X2.astype(np.float32) / 255.

predictions = model(X2, training=False)

num_rows = 2
num_cols = 3

def calculate_kcal(predict_array):
    kcal = 0
    for i in range(10):
        kcal += predict_array[i] * food_kcal[class_name[i]]
    return kcal


plt.figure(figsize=(3*2*num_cols, 4*num_rows))
plt.subplots_adjust(hspace=1.0)

for i in range(len(X2)):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X2[i])
    plt.xlabel("{} \nexpected : {:2.0f}kcal".format(Y2[i], calculate_kcal(predictions.numpy()[i])))
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plt.grid(False)    
    plt.xticks(range(N_CLASS), class_name, rotation=90)
    plt.yticks([])
    thisplot = plt.bar(range(N_CLASS), predictions.numpy()[i], color="#777777")
    plt.ylim([0, 1]) 
    predicted_label = np.argmax(predictions.numpy()[i])
    thisplot[predicted_label].set_color('red')

    print(Y2[i], calculate_kcal(predictions.numpy()[i]))
# Out:
# Bindaetteok 470.3401287394445
# cold_noodles 245.06752153480193
# japchae 820.5396656716689
# pork_barbecue 649.2053084999643
# tteokbokki 481.11887994652716
# yukgaejang 444.61517721952987
